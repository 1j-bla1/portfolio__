# %% [raw]
# ---
# layout: post
# title: Constellators - Conditionals HW
# description: These are the homework problems and popcorn hacks, created by Team Constellators.
# permalink: /csse/javascript/constellators/conditionals-hw
# author: Adya S, Niharika B, Salma Z, Anika S, Sophie H
# categories: [JavaScript]
# ---

# %% [markdown]
# ## **Conditionals**

# %% [markdown]
# ### <u>Popcorn Hack 1 - Simple Conditionals</u>
#
# Instructions:
# Finish the code in the cell below (fill in underlines and add lines of code) so it becomes a functioning conditional. What you make is up to you!
#
# **Examples of conditionals you could use:**
#
# 1) Define your mood today and give yourself ice cream if you're happy
# - challenge 1: add "else if" conditionals that echo different strings based on different moods
# - challenge 2: add user input to define a "mood" variable
#
# 2) Define the weather today and echo "It's sunny outside!" if it's sunny
# - challenge 1: add "else if" conditionals that define other weather
# - challenge 2: let the user input today’s weather and respond automatically
#
# 3) Define your age as a variable and check whether you are an adult or a child.
# - challenge 1: expand to add other categories using "else if" conditionals
# - challenge 2: create a random age generator and test the conditional multiple times to see different results
#
# The code is currently NOT functional. When you have completed this popcorn hack, the code should work. Have fun!

# %%
# %%html
#
# <div id="outputPH1">Results will appear here:<br></div>
#
# <p>
#     <label for="moodInput">Enter your mood (Type:, happy, sad, bored):</label>
#     <input type="text" id="moodInput" value="Type Mood Here">
#     <button onclick="checkMood()">Check Mood</button>
# </p>
#
# <script>
#
# //James Blazek Comment: This function runs all the code when the button in clicked. It runs every press of the button and checks the mood.
# function checkMood() {
#
#     const output = document.getElementById("outputPH1");
#
#     //James Blazek comment: This makes the mood based off what the user inputs. They can type either happy sad or bored. If you type anything else it will say I'm feeling okay.
#     let mood = document.getElementById("moodInput").value;
#
#      output.innerHTML = "Results will appear here:<br>";
#
#     if (mood === "happy") {
#         console.log("I'm feeling great!");
#         output.innerText += "I'm feeling great!";
#     } else if (mood === "sad") {
#         console.log("I'm feeling blue.");
#         output.innerText += "I'm feeling blue.";
#     }else if (mood === "bored") {
#         console.log("I'm feeling bored.");
#         output.innerText += "I'm feeling bored.";
#     } else {
#         console.log("I'm feeling okay.");
#         output.innerText += "I'm feeling okay.";
#     }
#
# //James Blazek comment: This code now outputs the mood to the screen and console and changes basaed off what you type in the input box.
# }
# </script>
# Out:
# <div id="outputPH1">Results will appear here:<br></div>
#
# <p>
#     <label for="moodInput">Enter your mood (Type:, happy, sad, bored):</label>
#     <input type="text" id="moodInput" value="Type Mood Here">
#     <button onclick="checkMood()">Check Mood</button>
# </p>
#
# <script>
#
# //James Blazek Comment: This function runs all the code when the button in clicked. It runs every press of the button and checks the mood.
# function checkMood() {
#
#     const output = document.getElementById("outputPH1");
#
#     //James Blazek comment: This makes the mood based off what the user inputs. They can type either happy sad or bored. If you type anything else it will say I'm feeling okay.
#     let mood = document.getElementById("moodInput").value;
#
#      output.innerHTML = "Results will appear here:<br>";
#
#     if (mood === "happy") {
#         console.log("I'm feeling great!");
#         output.innerText += "I'm feeling great!";
#     } else if (mood === "sad") {
# ...

# %% [markdown]
# ### <u>Popcorn Hack 2 - Vending Machine</u>
#
# Instructions:
# This hack is a bit more complicated than the first. Points will be awarded based on effort and completion.
#
# Analyze the block of code below. Then, complete the following instructions:
#
# You're hungry, so you go to your nearest vending machine for a snack. It makes you wonder if you'd be able to build your own. You can!... Digitally. Below, fill in the blanks so that when someone is prompted with food options, there are sub options within each food. (ex: Chocolate > Milk Chocolate)
#
# 1) **Create variables:**
# - snackChoice -> user input (prompt) to determine which random snack is chosen (number from 1-3)
#
# 2) **Add basic conditionals determining what type of snack was chosen**
#
# 3) **Add nested if statements for extra behavior**
#
# - Inside your chocolate condition:
#     - Add user input to determine what type of chocolate the user wants
# - Inside your candy condition:
#     - Add user input to determine what color candy the user wants
#
# 4) **Challenge (OPTIONAL):**
#
# - Make it so that there is a 10% chance of the vending machine giving you an extra cookie!

# %%
# %%html
#
# <div id="outputPH2">Results will appear here:<br></div>
#
# <script>
#
# (() => {
#
#     const output = document.getElementById("outputPH2");
#
# let snackChoice = prompt("Choose a number: 1, 2, or 3 to get a snack!");
#
#     if (snackChoice == "1") { // Fill in the condition for chocolate bar
#         let chocolateType = prompt("You got a chocolate bar! Choose your type: milk or dark?");
#
#         // Nested condition for chocolate type
#         if (chocolateType.toLowerCase() === "milk") { // Fill in milk
#             output.innerText += "You bought milk chocolate\n"; // Fill in message for milk chocolate
#         } else if (chocolateType.toLowerCase() === "dark") { // Fill in dark
#             output.innerText += "You bought dark choclate\n"; // Fill in message for dark chocolate
#         } else {
#             output.innerText += "That does not exist. Choose Milk or Dark Chocolate\n"; // Fill in message for unknown type
#         }
#
#     } else if (snackChoice == "2") { // Fill in the condition for chips
#         output.innerText += "You bought a bag of chips\n"; // Fill in message for chips
#
#     } else if (snackChoice == "3") { // Fill in the condition for candy
#         let candyColor = prompt("You got candy! Choose your color: red, green, or yellow?");
#
#         // Nested condition for candy color
#         if (candyColor.toLowerCase() === "red") { // Fill in red
#             output.innerText += "You got red candy\n"; // Fill in message for red candy
#         } else if (candyColor.toLowerCase() === "green") { // Fill in green
#             output.innerText += "You got green candy\n"; // Fill in message for green candy
#         } else if (candyColor.toLowerCase() === "yellow") { // Fill in yellow
#             output.innerText += "You got yellow candy\n"; // Fill in message for yellow candy
#         } else {
#             output.innerText += "That is not a candy we sell\n"; // Fill in message for unknown candy color
#         }
#
#     } else {
#         output.innerText += "That is not a choice for a snack. Type 1, 2, or 3\n"; // Fill in message for invalid snack choice
#     }
#
#     // Challenge: 10% chance of extra cookie
#     if (Math.random() < 0.1) { // How would you create a random number with a 10% chance of fitting some criteria?
#         output.innerText += "Bonus treat! The machine gives you an extra cookie!\n";
#     }
#
# })();
#
# </script>
# Out:
# <div id="outputPH2">Results will appear here:<br></div>
#
# <script>
#
# (() => {
#
#     const output = document.getElementById("outputPH2");
#
# let snackChoice = prompt("Choose a number: 1, 2, or 3 to get a snack!");
#
#     if (snackChoice == "1") { // Fill in the condition for chocolate bar
#         let chocolateType = prompt("You got a chocolate bar! Choose your type: milk or dark?");
#
#         // Nested condition for chocolate type
#         if (chocolateType.toLowerCase() === "milk") { // Fill in milk
#             output.innerText += "You bought milk chocolate\n"; // Fill in message for milk chocolate
#         } else if (chocolateType.toLowerCase() === "dark") { // Fill in dark
#             output.innerText += "You bought dark choclate\n"; // Fill in message for dark chocolate
#         } else {
#             output.innerText += "That does not exist. Choose Milk or Dark Chocolate\n"; // Fill in message for unknown type
#         }
#
# ...

# %% [markdown]
# ### <u>Homework</u>
#
# Complete the following questions in the next code block.
#
# 1) Create a variable called "temperature" that defines a temperature. If it's above 80 degrees, print "It’s hot outside!". Otherwise, print "It’s nice outside."
#
# 2) Create a variable called "score". If score >= 90 print "A", 80-89 print "B", 70-79 print "C", otherwise print "Needs improvement."
#
# 3) Add a function to your "score" variable that prompts the user to input their score.
#
# 4) Define a variable "number". If it’s even, print "Even Number"; otherwise, print "Odd number."
#
# 5) Instead of defining the variable "number," make the number a random integer from 1-10.
#
# 6) Define a variable called "day" (like 'Monday', 'Tuesday', etc.) and use a switch statement to print a message for that day.
#
# 7) Add statements to the previous conditional: If today is 'Saturday' or 'Sunday', print "Weekend!"; else print "Weekday!".
#
# 8) Create a boolean called "loggedIn" (true or false). If true, print "Welcome back!", otherwise print "Please log in."
#
# 9) Define a variable "weather". If it's raining, print "It's raining." Else, print "Go outside, it's a nice day today!"
#
# 10) **Extra Credit:** Submit the original OOP Breakout Game Code (found on [OpenCS](https://github.com/Open-Coding-Society/pages/blob/main/hacks/breakout/breakout.md?plain=1)) after making the following edits:
# - Add a conditional to the game that changes the color of the ball every time it hits the wall or another brick.
# - Try making the ball do something different when it collides (ex: speed up, shrink, glow).
# - Make sure your code is functional before you submit!
# - Have fun!

# %%
# %%html
#
# <div style="margin-top: 15px; padding: 10px; border: 1px solid #ccc;">
#     <label for="userScore">Problem 3: Enter Score (0-100):</label>
#     <input type="text" id="userScore" value="87" style="width: 50px;">
#     <button onclick="checkScore()">Grade Score</button>
# </div>
#
# <div id="outputHW" style="margin-top: 10px; padding: 10px; border: 1px solid #aaa;">
#     <strong>Results will appear here:</strong><br>
# </div>
#
# <script>
#
# (() => {
#
#     const output = document.getElementById("outputHW");
#
#     console.log("Code, code, code!");
#     output.innerText += "Code, code, code!\n";
#
#     // YOUR CODE HERE
#
#     // Part 1. Temperature
#
#     //James Comment. This works by making a variable temperature that is equal to any value. The if statement checks if it is greater than 80
#     //If temperature is greater than 80 then it will display toasty wheather. If not it will say amazing weather. In my example it outputs amzing weather is 80 is not greater than 80.
#     let temperature= 80;
#
#     if (temperature > 80){
#
#          output.innerText += "Problem 1: It is very toasty outside\n";
#          console.log("Problem 1: It is very toasty outside");
#     } else {
#         output.innerText += " Problem 1: It is amazing weather today\n";
#         console.log("Problem 1: It is amazing weather today")
#     }
#
#     //Part 2. Score
#
#     //James Comment: This sets the score as 87. When this code runs the score is greater than 80 makiing it output that you got a b
#     let score= 87;
#
#     if (score>=90) {
#         output.innerText += "Problem 2: Good job, you got a A\n";
#         console.log("Problem 2: Good job, you got a A");
#     } else if (score>=80) {
#       output.innerText += "Problem 2: You got a B\n";
#       console.log("Problem 2: You got a B")
#     } else if (score>=70) {
#         output.innerText += "Problem 2: You got a C, Needs improvement\n";
#         console.log("Problem 2: You got a C, Needs improvement")
#     }
#
# //Part 4. Number Variable
#
# //James Comment: The number is 67 right now. I then use modulo which was taught in a prior lesson and see how many times 2 can go into the number. If the number was even then 2 can go into. If odd then 2 does't work
# //After the quation hapens depending on if it is true or false it will display that it is a even or odd number. In my case I choice 67 so that is a odd number.
# let number = 67;
#
# if (number % 2 === 0){
#      output.innerText += "Problem 4: " + number + " is a even number\n";
#      console.log("Problem 4: " + number + " is a even number\n");
# } else {
#      output.innerText += "Problem 4: " + number + " is a odd number\n";
#      console.log("Problem 4: " + number + " is a even number\n");
# }
#
# //Part 5. Random Number between 1 and 10
#
# //James comment:This makes the variable number equal a random number between 1 and 10. It than uses the same modulo strategy from the previous question to output
# number = Math.floor(Math.random() * 10) + 1;
#
# if (number % 2 === 0) {
#     output.innerText += "Problem 5: " +number +" number is an even number\n";
#     console.log("Problem 5: " +number +" number is an even number\n");
# } else {
#     output.innerText += "Problem 5: " +number +" number is an odd number\n";
#     console.log("Problem 5: " +number +" number is an odd number\n");
# }
#
# //Part 6. Day Variable
#
#
# // James comment I have used a switch statement for all days of the week allowing them to be printed. I have also added cases for each day so it checks each case till it finds the day that matches with the day variable. When this hapens it prints the message.
# let day = "Sunday"
#
# switch (day) {
#   case "Monday":
#     output.innerText += "Problem 6: Monday: Beginning of the week. BOOO!\n";
#     console.log("Problem 6: Monday: Beginning of the week. BOOO!");
#     break;
#   case "Tuesday":
#     output.innerText += "Problem 6: Tuesday: It is TACO TUESDAY!!!\n";
#     console.log("Problem 6: Tuesday: It is TACO TUESDAY!!!");
#     break;
#   case "Wednesday":
#     output.innerText += "Problem 6: Wednesday: Half way to the weekend.\n";
#     console.log("Problem 6: Wednesday: Half way to the weekend.");
#     break;
#   case "Thursday":
#     output.innerText += "Problem 6: Thursday: Almost the weekend\n";
#     console.log("Problem 6: Thursday: Almost the weekend");
#     break;
#   case "Friday":
#     output.innerText += "Problem 6: Friday: Last day till weekend\n";
#     console.log("Problem 6: Friday: Last day till weekend");
#     break;
#   case "Saturday":
#     output.innerText += "Problem 6: Saturday: Time to watch football.\n";
#     console.log("Problem 6: Saturday: Time to watch football.");
#     break;
#   case "Sunday":
#     output.innerText += "Problem 6: Sunday: School is tomorrow :(\n";
#     console.log("Problem 6: Sunday: School is tomorrow :(");
#     break;
#   default:
#     output.innerText += "Problem 6: Not a valid day.\n";
#     console.log("Problem 6: Not a valid day.");
# }
#
# // Part 7. Weekend or Weekday check
#
# // James comment: This checks if the day is Saturday or Sunday and prints "Weekend!" if it is this day. If it is not saturday or sunday then it prints "Weekday!".
# if (day === "Saturday" || day === "Sunday") {
#     output.innerText += "Problem 7: Weekend!\n";
#     console.log("Problem 7: Weekend!");
# } else {
#     output.innerText += "Problem 7: Weekday!\n";
#     console.log("Problem 7: Weekday!");
# }
#
# //Part 8. Logged in check
#
# //James Comment: I set loggedin to false. If loggedin was true then it would display welcome back. Since it is false the code outputs "Please Log In" instead.
#  let loggedin= false;
#
#  if (loggedin===true) {
#     output.innerText += "Problem 8: Welcome Back!\n";
#     console.log("Problem 8: Welcome Back!");
#  } else {
#     output.innerText += "Problem 8: Please Log In\n"
#     console.log("Problem 8: Please Log In");
#  }
#
# //Part 9. Weather
#
#  let weather = "rain";
#
#  if (weather === "rain"){
#   output.innerText += "Problem 9: It's Raining\n"
#     console.log("Problem 9: It's Raining");
#  } else {
#   output.innerText += "Problem 9: Go outside, It's a nice day today.\n"
#   console.log("Problem 9: Go outside, It's a nice day today.")
#  }
#
#
# //James Comment: All homework problems 1 through 9 are completed. I hope you enjoy the code I have made.
#
#
# })();
#
#     //Part 3. Score Input// This one took a while
#
#     //James comment: This code works on the text input. On the top of the code is where button is created. When it is pressed it runs this functions allowing your score to be outputed
# function checkScore() {
#     const output = document.getElementById("outputHW");
#     const userScore = parseInt(document.getElementById("userScore").value);
#
#     output.innerText += "\nYour Score:\n";
#
#     if (userScore >= 90) {
#         output.innerText += "You got an A \n";
#     } else if (userScore >= 80) {
#         output.innerText += "You got a B \n";
#     } else if (userScore >= 70) {
#         output.innerText += "You got a C, Needs improvement \n";
#     } else {
#         output.innerText += "Under 70%: You need to study more \n";
#     }
# }
#
#
# </script>
# Out:
# <div style="margin-top: 15px; padding: 10px; border: 1px solid #ccc;">
#     <label for="userScore">Problem 3: Enter Score (0-100):</label>
#     <input type="text" id="userScore" value="87" style="width: 50px;">
#     <button onclick="checkScore()">Grade Score</button>
# </div>
#
# <div id="outputHW" style="margin-top: 10px; padding: 10px; border: 1px solid #aaa;">
#     <strong>Results will appear here:</strong><br>
# </div>
#
# <script>
#
# (() => {
#
#     const output = document.getElementById("outputHW");
#
#     console.log("Code, code, code!");
#     output.innerText += "Code, code, code!\n";
#
#     // YOUR CODE HERE
#
#     // Part 1. Temperature
#
#     //James Comment. This works by making a variable temperature that is equal to any value. The if statement checks if it is greater than 80
#     //If temperature is greater than 80 then it will display toasty wheather. If not it will say amazing weather. In my example it outputs amzing weather is 80 is not greater than 80.
# ...
